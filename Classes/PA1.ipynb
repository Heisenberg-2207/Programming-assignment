# %%
import Algorithms
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# SARSA

# %%
#choose number 0 to 5 to enter a argument for world number
#sarsa
for index in range(0,6):
    alpha = 0.4
    gamma = 0.9
    episodes =5000
    env  = Algorithms.world(world_num = index)
    Problem = Algorithms.Solver(env,episodes,alpha,gamma,index)
    Problem.solve(Problem.choose_action_softmax,Problem.sarsa) 
    
    #Q, rewards, steps = algorithm.sarsa(env, Q, alpha = alpha, gamma = gamma, plot_heat=True, choose_action= algorithm.choose_action_softmax, episodes = episodes, world_num=index)
    #algorithm.reward_steps(env,0, algorithm.sarsa)
# Out:
#  13%|█▎        | 631/5000 [00:02<00:18, 240.20it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       7 env  = algorithm.world(world_num = index)
#       8 Problem = algorithm.Solver(env,episodes,alpha,gamma,index)
# ----> 9 Problem.solve(Problem.choose_action_softmax,Problem.sarsa)
#      11 #Q, rewards, steps = algorithm.sarsa(env, Q, alpha = alpha, gamma = gamma, plot_heat=True, choose_action= algorithm.choose_action_softmax, episodes = episodes, world_num=index)
#      12 #algorithm.reward_steps(env,0, algorithm.sarsa)
#
# File ~/Acads/Sem6/RL/Programming-assignment-main/programming assignment 1/algorithm.py:45, in Solver.solve(self, policy, algorithm)
#      43 self.algorithm = algorithm
#      44 self.reset()
# ---> 45 self.sarsa()
#      46 self.plot_solver()
#
# File ~/Acads/Sem6/RL/Programming-assignment-main/programming assignment 1/algorithm.py:94, in Solver.sarsa(self, plot_heat)
#      90     steps += 1
#      92     self.state, self.action = self.next_state, self.next_action
# ---> 94     if self.state in self.env.goal_states_seq:
#      95         break
#      97 episode_rewards[ep] = tot_reward
#
# KeyboardInterrupt:

# %% [markdown]
# Q_Learning

# %%
#choose number 0 to 5 to enter a argument for world number
#sarsa
for index in range(0,6):
    env  = algorithm.world(world_num = index)
    Problem = algorithm.Solver(env,5000,index)
    Problem.solve(Problem.choose_action_softmax,Problem.qlearning) 
    alpha = 0.4
    gamma = 0.9
    episodes =5000
    #Q, rewards, steps = algorithm.sarsa(env, Q, alpha = alpha, gamma = gamma, plot_heat=True, choose_action= algorithm.choose_action_softmax, episodes = episodes, world_num=index)
    #algorithm.reward_steps(env,0, algorithm.sarsa)
# Out:
#   8%|▊         | 393/5000 [00:03<00:38, 119.44it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 env  = algorithm.world(world_num = index)
#       5 Problem = algorithm.Solver(env,5000,index)
# ----> 6 Problem.solve(Problem.choose_action_softmax,Problem.qlearning)
#       7 alpha = 0.4
#       8 gamma = 0.9
#
# File ~/Acads/Sem6/RL/Programming-assignment-main/programming assignment 1/algorithm.py:43, in Solver.solve(self, policy, algorithm)
#      41 self.algorithm = algorithm
#      42 self.reset()
# ---> 43 self.sarsa()
#      44 self.plot_solver()
#
# File ~/Acads/Sem6/RL/Programming-assignment-main/programming assignment 1/algorithm.py:81, in Solver.sarsa(self, alpha, gamma, plot_heat)
#      79 while not done:
#      80     self.next_state, reward, done = self.env.step(self.state, self.action)
# ---> 81     self.next_action = choose_action(self.next_state)
#      83     # Update equation for SARSA
#      84     self.Q[self.state, self.action] += alpha * (reward + gamma * self.Q[self.next_state, self.next_action] - self.Q[self.state, self.action])
#
# File ~/Acads/Sem6/RL/Programming-assignment-main/programming assignment 1/algorithm.py:37, in Solver.choose_action_softmax(self, state, rg)
#      35 def choose_action_softmax(self,state, rg=rg):
#      36        action_probs = softmax(self.Q[state])
# ---> 37        return rg.choice(len(actions), p=action_probs)
#
# KeyboardInterrupt:
