# %%
import algorithm
import numpy as np
import matplotlib.pyplot as plt

# %%
#choose number 0 to 5 to enter a argument for world number
for index in range(0,5):
    env  = algorithm.world(world_num = 1)
    Q = np.zeros((env.num_states, env.num_actions))
    alpha0 = 0.4
    gamma = 0.9
    episodes =5000
    Q, rewards, steps = algorithm.sarsa(env, Q, alpha = alpha0, gamma = gamma, plot_heat=True, choose_action= algorithm.choose_action_softmax, episodes = episodes)
# Out:
#  56%|█████▌    | 2799/5000 [00:13<00:10, 212.27it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       6 gamma = 0.9
#       7 episodes =5000
# ----> 8 Q, rewards, steps = algorithm.sarsa(env, Q, alpha = alpha0, gamma = gamma, plot_heat=True, choose_action= algorithm.choose_action_softmax, episodes = episodes, index = index)
#
# File d:\heisen\IITM studies\3rd year\sem 6\CS6700\Programming assignment\programming assignment 1\algorithm.py:59, in sarsa(env, Q, alpha, gamma, plot_heat, choose_action, episodes, index)
#      57     if (ep+1) % print_freq == 0 and plot_heat:
#      58         clear_output(wait=True)
# ---> 59         plot_Q(Q, message="Episode %d: Reward: %f, Steps: %.2f, Qmax: %.2f, Qmin: %.2f" % (ep+1, np.mean(episode_rewards[ep-print_freq+1:ep]),
# ...
