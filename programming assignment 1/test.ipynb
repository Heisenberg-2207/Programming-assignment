# %%
import algorithm
import numpy as np
import matplotlib.pyplot as plt

# %%
#choose number 0 to 5 to enter a argument for world number
#sarsa
for index in range(0,6):
    env  = algorithm.world(world_num = index)
    Q = np.zeros((env.num_states, env.num_actions))
    alpha = 0.4
    gamma = 0.9
    episodes =5000
    Q, rewards, steps = algorithm.sarsa(env, Q, alpha = alpha, gamma = gamma, plot_heat=True, choose_action= algorithm.choose_action_softmax, episodes = episodes, world_num=index)
    algorithm.reward_steps(env,0, algorithm.sarsa)
# Out:
#  43%|████▎     | 2163/5000 [00:12<00:16, 171.70it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 10
#       8 episodes =5000
#       9 #Q, rewards, steps = algorithm.sarsa(env, Q, alpha = alpha, gamma = gamma, plot_heat=True, choose_action= algorithm.choose_action_softmax, episodes = episodes, world_num=index)
# ---> 10 algorithm.reward_steps(env,0, algorithm.sarsa)
#
# File d:\heisen\IITM studies\3rd year\sem 6\CS6700\Programming assignment\programming assignment 1\algorithm.py:133, in reward_steps(env, world_num, policy, episodes)
#     129         sleep(0.2)
#     130     print("Steps: %d, Total Reward: %d"%(steps, tot_reward))
# --> 133 def reward_steps(env, world_num, policy, episodes = 5000):
#     134     num_expts = 5
#     135     reward_avgs = []
#
# ...

# %%
#choose number 0 to 5 to enter a argument for world number
#sarsa
for index in range(0,1):
    env  = algorithm.world(world_num = index)
    Q = np.zeros((env.num_states, env.num_actions))
    alpha = 0.4
    gamma = 0.9
    episodes =5000
    Q, rewards, steps = algorithm.qlearning(env, Q, alpha = alpha, gamma = gamma, plot_heat=True, choose_action= algorithm.choose_action_softmax, episodes = episodes, world_num=index)
    algorithm.reward_steps(env,0,algorithm.qlearning)
# Out:
# 100%|██████████| 5000/5000 [00:16<00:00, 305.81it/s]
